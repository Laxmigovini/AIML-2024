# %%
#part2
import numpy as np
people=np.array(['kiran','arun','vijay','varun'])
age=np.array([25,30,35,40])
height=np.array([145,151,165,173])
weight=np.array([45,55,65,75])
import matplotlib.pyplot as plt
plt.title("relation between height and weight")
plt.xlabel(height)
plt.ylabel(weight)
plt.scatter(height,weight)
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
plt.title("relation between height and weight")
plt.xlabel(height)
plt.ylabel(weight)
plt.bar(height,weight)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.title("relation between height and weight")
plt.xlabel("height")
plt.ylabel("weight")
plt.hist(height,color='red')
plt.show()

# %%
import pandas as pd

people = ['kiran', 'arun', 'vijay', 'varun']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]

data = {'Person': people,'Age': Age, 'Height': height, 'Weight': weight}

# Create a DataFrame
health_care_dataset = pd.DataFrame(data)

# Display the dataset
print(health_care_dataset)
# Out:
#   Person  Age  Height  Weight
# 0  kiran   25     145      45
# 1   arun   30     151      55
# 2  vijay   35     165      65
# 3  varun   40     173      75

# %%
import matplotlib.pyplot as plt

# Scatter plot
plt.scatter(health_care_dataset['Age'], health_care_dataset['Weight'], s=health_care_dataset['Height'], alpha=0.7)

# Title and labels
plt.title('Health Care Data Analysis')
plt.xlabel('Age')
plt.ylabel('Weight')

# Explanation
plt.text(30, 65, 'Marker size represents height', fontsize=10, color='red')

# Display the plot
plt.show()
